# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")  # load a pretrained model (recommended for training)
results = model.train(data="data.yaml", epochs=50, imgsz=640, augment=True)
# Out:
# Ultralytics 8.3.55 🚀 Python-3.12.7 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7940MiB)
# ...

# %%
# !yolo val model=/home/nova/Videos/Google-ai-hack/YOLO.v15-yee-.yolov9/runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics 8.3.51 🚀 Python-3.12.7 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7940MiB)
# YOLO11n summary (fused): 238 layers, 2,582,932 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/nova/Videos/Google-ai-hack/YOLO.v15-yee-.yolov9/valid/labels
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2, len(boxes) = 782. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# /home/nova/anaconda3/lib/python3.12/site-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !yolo predict model=/home/nova/Videos/Google-ai-hack/baseball detection v1.v4i.yolov8/runs/detect/train2/weights/best.pt source=/home/nova/Videos/images.jpeg
# Out:
# Traceback (most recent call last):
#   File "/home/nova/anaconda3/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/home/nova/.local/lib/python3.12/site-packages/ultralytics/cfg/__init__.py", line 901, in entrypoint
#     check_dict_alignment(full_args_dict, {a: ""})
#   File "/home/nova/.local/lib/python3.12/site-packages/ultralytics/cfg/__init__.py", line 486, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'detection' is not a valid YOLO argument. Similar arguments are i.e. ['detect'].
#
#     Arguments received: ['yolo', 'predict', 'model=/home/nova/Videos/Google-ai-hack/baseball', 'detection', 'v1.v4i.yolov8/runs/detect/train2/weights/best.pt', 'source=/home/nova/Videos/images.jpeg']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of {'pose', 'obb', 'detect', 'classify', 'segment'}
# ...

# %%
model.predict(source="/home/nova/Videos/image.jpeg", show=True, conf=0.25)
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/nova/.local/lib/python3.12/site-packages/cv2/qt/plugins"
# image 1/1 /home/nova/Videos/image.jpeg: 448x640 1 Ball, 35.3ms
# Speed: 1.6ms preprocess, 35.3ms inference, 283.1ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Ball', 1: 'Bat'}
#  obb: None
#  orig_img: array([[[ 51,  57,  52],
#          [ 79,  85,  80],
#          [107, 112, 110],
#          ...,
#          [ 78,  77,  73],
#          [ 78,  77,  73],
#          [ 78,  77,  73]],
#
#         [[ 70,  76,  71],
#          [ 99, 105, 100],
#          [131, 136, 134],
#          ...,
#          [ 80,  79,  75],
#          [ 80,  79,  75],
#          [ 80,  79,  75]],
#
#         [[ 93, 100,  93],
#          [121, 128, 121],
#          [150, 157, 152],
#          ...,
# ...

# %%
from ultralytics import YOLO
import cv2
from ultralytics.utils.plotting import Annotator
import matplotlib.pyplot as plt

# Load the YOLO model
model = YOLO('/home/nova/Videos/Google-ai-hack/RoboUmp.v4i.yolov11/runs/detect/train/weights/best.pt')  # load a pretrained YOLO segmentation model

# Open the video file
cap = cv2.VideoCapture("/home/nova/Videos/try.mp4")

# Get the width, height, and FPS of the video
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Set up video writer to save output
writer = cv2.VideoWriter("Ultralytics_circle_annotation.avi", cv2.VideoWriter_fourcc(*"MJPG"), fps, (w, h))

# Loop through the video frames
while True:
    ret, im0 = cap.read()
    if not ret:
        break

    # Create an Annotator instance for the current frame
    annotator = Annotator(im0)

    # Perform detection
    results = model.predict(im0)

    # Get the detected bounding boxes and classes
    boxes = results[0].boxes.xyxy.tolist()  # Get bounding boxes as a list
    clss = results[0].boxes.cls.tolist()  # Get classes as a list

    # Annotate the image with circles and labels
    for box, cls in zip(boxes, clss):
        annotator.circle_label(box, label=str(int(cls)))  # Using str() for the label

    # Write the annotated frame to the output video
    writer.write(im0)

    # Show the annotated frame
    cv2.imshow("Ultralytics Circle Annotation", im0)

    # Exit the loop if the user presses 'q'
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Release resources after processing
writer.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 4.7ms
# Speed: 1.2ms preprocess, 4.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 3.9ms
# Speed: 1.3ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 4.3ms
# Speed: 1.2ms preprocess, 4.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 10.3ms
# Speed: 2.1ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 4.1ms
# Speed: 1.4ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 4.4ms
# ...

# %%
from ultralytics import YOLO
import cv2
from ultralytics.utils.plotting import Annotator
import matplotlib.pyplot as plt

# Load the YOLO model
model = YOLO('/home/nova/Videos/Google-ai-hack/RoboUmp.v4i.yolov11/runs/detect/train/weights/best.pt')  # load a pretrained YOLO model

# Open the video file
cap = cv2.VideoCapture("/home/nova/Videos/try.mp4")

# Get the width, height, and FPS of the video
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Set up video writer to save output
writer = cv2.VideoWriter("Ultralytics_circle_annotation.avi", cv2.VideoWriter_fourcc(*"MJPG"), fps, (w, h))

# Loop through the video frames
while True:
    ret, im0 = cap.read()
    if not ret:
        break

    # Create an Annotator instance for the current frame
    annotator = Annotator(im0)

    # Perform detection
    results = model.predict(im0)

    # Get the detected bounding boxes and classes
    boxes = results[0].boxes.xyxy.tolist()  # Get bounding boxes as a list
    clss = results[0].boxes.cls.tolist()  # Get classes as a list

    # Annotate the image with circles and class names
    for box, cls in zip(boxes, clss):
        class_name = model.names[int(cls)]  # Get class name from the model
        annotator.circle_label(box, label=class_name)  # Annotating with the class name

    # Write the annotated frame to the output video
    writer.write(im0)

    # Show the annotated frame
    cv2.imshow("Ultralytics Circle Annotation", im0)

    # Exit the loop if the user presses 'q'
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Release resources after processing
writer.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 3.5ms
# Speed: 1.1ms preprocess, 3.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Length of label is 7, initial 3 label characters will be considered for circle annotation!
# Length of label is 6, initial 3 label characters will be considered for circle annotation!
# Length of label is 9, initial 3 label characters will be considered for circle annotation!
#
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 4.4ms
# Speed: 1.3ms preprocess, 4.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Length of label is 7, initial 3 label characters will be considered for circle annotation!
# Length of label is 6, initial 3 label characters will be considered for circle annotation!
# Length of label is 9, initial 3 label characters will be considered for circle annotation!
#
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 4.8ms
# ...

# %%
from ultralytics import YOLO
import cv2
from ultralytics.utils.plotting import Annotator
import numpy as np

# Load the YOLO model
model = YOLO('/home/nova/Videos/Google-ai-hack/RoboUmp.v4i.yolov11/runs/detect/train/weights/best.pt')  # load a pretrained YOLO model

# Open the video file
cap = cv2.VideoCapture("/home/nova/Videos/try.mp4")

# Get the width, height, and FPS of the video
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Set up video writer to save output
writer = cv2.VideoWriter("Ultralytics_circle_annotation.avi", cv2.VideoWriter_fourcc(*"MJPG"), fps, (w, h))

# Variables for physics calculations
previous_positions = {}
g = 9.81  # Acceleration due to gravity (m/s^2)
pixels_to_meter = 0.01  # Conversion factor (adjust based on your setup)

# Loop through the video frames
while True:
    ret, im0 = cap.read()
    if not ret:
        break

    # Create an Annotator instance for the current frame
    annotator = Annotator(im0)

    # Perform detection
    results = model.predict(im0)

    # Get the detected bounding boxes and classes
    boxes = results[0].boxes.xyxy.tolist()  # Get bounding boxes as a list
    clss = results[0].boxes.cls.tolist()  # Get classes as a list

    # Annotate the image with circles and class names
    for box, cls in zip(boxes, clss):
        class_name = model.names[int(cls)]  # Get class name from the model
        annotator.circle_label(box, label=class_name)  # Annotating with the class name

        # Calculate center of the bounding box
        x_center = (box[0] + box[2]) / 2
        y_center = (box[1] + box[3]) / 2
        current_position = (x_center, y_center)

        # Physics calculations for each detected object
        if class_name in previous_positions:
            prev_x, prev_y = previous_positions[class_name]
            dx = (current_position[0] - prev_x) * pixels_to_meter
            dy = (prev_y - current_position[1]) * pixels_to_meter  # Inverted y-axis for screen coordinates
            distance = np.sqrt(dx**2 + dy**2)
            velocity = distance * fps  # Exit velocity in m/s

            if dx != 0:
                launch_angle = np.degrees(np.arctan(dy / dx))  # Launch angle in degrees
            else:
                launch_angle = 90.0  # Vertical launch

            # Display physics data on the frame using cv2.putText
            physics_info = f"Vel: {velocity:.2f} m/s, Angle: {launch_angle:.1f}°"
            cv2.putText(im0, physics_info, (int(box[0]), int(box[1]) - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

            # Estimate hit distance (assuming simple projectile motion)
            if velocity > 0:
                hit_distance = (velocity**2 * np.sin(2 * np.radians(launch_angle))) / g
                hit_info = f"HitDist: {hit_distance:.2f} m"
                cv2.putText(im0, hit_info, (int(box[0]), int(box[1]) - 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

        # Update previous positions
        previous_positions[class_name] = current_position

    # Write the annotated frame to the output video
    writer.write(im0)

    # Show the annotated frame
    cv2.imshow("Ultralytics Circle Annotation", im0)

    # Exit the loop if the user presses 'q'
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Release resources after processing
writer.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 59.0ms
# Speed: 3.5ms preprocess, 59.0ms inference, 529.2ms postprocess per image at shape (1, 3, 384, 640)
# Length of label is 7, initial 3 label characters will be considered for circle annotation!
# Length of label is 6, initial 3 label characters will be considered for circle annotation!
# Length of label is 9, initial 3 label characters will be considered for circle annotation!
#
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 7.9ms
# Speed: 3.2ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Length of label is 7, initial 3 label characters will be considered for circle annotation!
# Length of label is 6, initial 3 label characters will be considered for circle annotation!
# Length of label is 9, initial 3 label characters will be considered for circle annotation!
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/nova/.local/lib/python3.12/site-packages/cv2/qt/plugins"
# ...

# %%
from ultralytics import YOLO
import cv2
from ultralytics.utils.plotting import Annotator
import numpy as np

# Load the YOLO model
model = YOLO('/home/nova/Videos/Google-ai-hack/RoboUmp.v4i.yolov11/runs/detect/train/weights/best.pt')

# Open the video file
cap = cv2.VideoCapture("/home/nova/Videos/try.mp4")

# Get video properties
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
writer = cv2.VideoWriter("Ultralytics_circle_annotation.avi", cv2.VideoWriter_fourcc(*"MJPG"), fps, (w, h))

# Constants for physics calculations
g = 9.81  # Gravity (m/s²)
pixels_to_meter = 0.01  # Adjust based on your setup

# Variables to store object tracking data
previous_positions = {}
previous_times = {}

# Loop through video frames
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Create an Annotator instance for the current frame
    annotator = Annotator(frame)

    # Perform detection
    results = model.predict(frame)

    # Get detected bounding boxes and classes
    boxes = results[0].boxes.xyxy.tolist()  # Bounding boxes as a list
    clss = results[0].boxes.cls.tolist()  # Classes as a list

    # Annotate and calculate physics for each detected object
    current_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000.0  # Current time in seconds
    for box, cls in zip(boxes, clss):
        class_name = model.names[int(cls)]  # Get class name
        x_center = (box[0] + box[2]) / 2
        y_center = (box[1] + box[3]) / 2
        current_position = (x_center, y_center)

        # Physics calculations
        if class_name in previous_positions:
            # Calculate time delta
            prev_position = previous_positions[class_name]
            prev_time = previous_times[class_name]
            dt = current_time - prev_time

            # Velocity components (dx/dt and dy/dt in m/s)
            dx = (current_position[0] - prev_position[0]) * pixels_to_meter
            dy = (prev_position[1] - current_position[1]) * pixels_to_meter  # Inverted y-axis
            velocity_x = dx / dt
            velocity_y = dy / dt

            # Exit velocity magnitude
            exit_velocity = np.sqrt(velocity_x**2 + velocity_y**2)

            # Launch angle
            launch_angle = np.degrees(np.arctan2(velocity_y, velocity_x))

            # Hit distance using projectile motion formula
            if velocity_y > 0:
                hit_distance = (exit_velocity**2 * np.sin(2 * np.radians(launch_angle))) / g
            else:
                hit_distance = 0.0

            # Annotate physics data on the frame
            physics_info = f"Vel: {exit_velocity:.2f} m/s, Angle: {launch_angle:.1f}°"
            hit_info = f"HitDist: {hit_distance:.2f} m"
            cv2.putText(frame, physics_info, (int(box[0]), int(box[1]) - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
            cv2.putText(frame, hit_info, (int(box[0]), int(box[1]) - 30),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

        # Update position and time for the next frame
        previous_positions[class_name] = current_position
        previous_times[class_name] = current_time

        # Annotate the object
        annotator.circle_label(box, label=class_name)

    # Write the annotated frame to the output video
    writer.write(frame)

    # Display the annotated frame
    cv2.imshow("Ultralytics Circle Annotation", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# Release resources
writer.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 batter, 1 pitcher, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Length of label is 7, initial 3 label characters will be considered for circle annotation!
# Length of label is 6, initial 3 label characters will be considered for circle annotation!
#
# 0: 384x640 1 batter, 1 pitcher, 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Length of label is 7, initial 3 label characters will be considered for circle annotation!
# Length of label is 6, initial 3 label characters will be considered for circle annotation!
#
# 0: 384x640 1 batter, 1 pitcher, 11.1ms
# Speed: 3.5ms preprocess, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Length of label is 7, initial 3 label characters will be considered for circle annotation!
# Length of label is 6, initial 3 label characters will be considered for circle annotation!
#
# ...

# %%
from ultralytics import YOLO
import cv2
import numpy as np

# Load YOLO model
model = YOLO('/home/nova/Videos/Google-ai-hack/RoboUmp.v4i.yolov11/runs/detect/train/weights/best.pt')

# Video path and capture setup
video_path = "/home/nova/Videos/try.mp4"
cap = cv2.VideoCapture(video_path)

# Video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_interval = fps  # Process one frame per second
g = 9.81  # Acceleration due to gravity (m/s^2)

# Calculate pixels-to-meter scaling factor
stadium_length_meters = 800  # Real-world stadium length in meters
stadium_pixel_length = 3920  # Example pixel length (update with actual value)
pixels_to_meter = stadium_length_meters / stadium_pixel_length
print(f"Pixels-to-Meter Scaling Factor: {pixels_to_meter:.4f} meters per pixel")

# Tracking variables
previous_positions = {}
previous_times = {}
results_list = []

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Get current frame ID
    frame_id = int(cap.get(cv2.CAP_PROP_POS_FRAMES))
    if frame_id % frame_interval != 0:
        continue

    # Predict with YOLO
    results = model.predict(frame)
    boxes = results[0].boxes.xyxy.tolist()
    clss = results[0].boxes.cls.tolist()
    current_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000.0  # Time in seconds

    for box, cls in zip(boxes, clss):
        class_name = model.names[int(cls)]
        if class_name != "pitcher":  # Process only objects labeled as "pitcher"
            continue

        # Calculate current position (center of bounding box)
        x_center = (box[0] + box[2]) / 2
        y_center = (box[1] + box[3]) / 2
        current_position = (x_center, y_center)

        if class_name in previous_positions:
            prev_position = previous_positions[class_name]
            prev_time = previous_times[class_name]
            dt = current_time - prev_time

            if dt > 0:
                # Calculate velocity and derived parameters
                dx = (current_position[0] - prev_position[0]) * pixels_to_meter
                dy = (prev_position[1] - current_position[1]) * pixels_to_meter
                
                velocity_x = dx / dt
                velocity_y = dy / dt
                exit_velocity = np.sqrt(velocity_x**2 + velocity_y**2)
                launch_angle = np.degrees(np.arctan2(velocity_y, velocity_x))

                # Debugging output
                print(f"Frame {frame_id}:")
                print(f"  dx (m): {dx}, dy (m): {dy}, dt (s): {dt}")
                print(f"  Velocity X: {velocity_x:.2f} m/s, Velocity Y: {velocity_y:.2f} m/s")
                print(f"  ExitVelocity: {exit_velocity:.2f} m/s, LaunchAngle: {launch_angle:.1f}°")

                # Calculate hit distance
                hit_distance = (exit_velocity**2 * np.sin(2 * np.radians(launch_angle))) / g
                results_list.append({
                    "ExitVelocity": round(exit_velocity, 2),
                    "HitDistance": round(hit_distance, 2),
                    "LaunchAngle": round(launch_angle, 1),
                    "Timestamp": round(current_time, 2)
                })
        
        # Update previous positions and times
        previous_positions[class_name] = current_position
        previous_times[class_name] = current_time

cap.release()

# Print final results
print(f"\nFinal Results ({len(results_list)} frames):")
for result in results_list:
    print(f"ExitVelocity: {result['ExitVelocity']} m/s, "
          f"HitDistance: {result['HitDistance']} m, "
          f"LaunchAngle: {result['LaunchAngle']}°, "
          f"Timestamp: {result['Timestamp']} s")
# Out:
# Pixels-to-Meter Scaling Factor: 0.2041 meters per pixel
#
# 0: 384x640 1 batter, 1 pitcher, 6.8ms
# Speed: 2.2ms preprocess, 6.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 9.7ms
# Speed: 2.7ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Frame 58:
#   dx (m): -2.519581074617347, dy (m): -1.1468256736288265, dt (s): 0.9676333333333335
#   Velocity X: -2.60 m/s, Velocity Y: -1.19 m/s
#   ExitVelocity: 2.86 m/s, LaunchAngle: -155.5°
#
# 0: 384x640 1 baseball, 1 batter, 1 homeplate, 1 pitcher, 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 87:
#   dx (m): 2.0067113759566326, dy (m): -12.857874656210141, dt (s): 0.9676333333333333
#   Velocity X: 2.07 m/s, Velocity Y: -13.29 m/s
#   ExitVelocity: 13.45 m/s, LaunchAngle: -81.1°
#
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 6.5ms
# ...

# %%
print(f"Number of results collected: {len(results_list)}")
print("Sample of last detection:", boxes, clss)
# Out:
# Number of results collected: 0
# Sample of last detection: [[409.7852783203125, 119.71630859375, 702.9144287109375, 720.0]] [3.0]

# %%
print("Class mapping:", model.names)
# Out:
# Class mapping: {0: 'baseball', 1: 'batter', 2: 'homeplate', 3: 'pitcher'}

# %%
from ultralytics import YOLO
import cv2
import numpy as np

# Load YOLO model
model = YOLO('/home/nova/Videos/Google-ai-hack/RoboUmp.v4i.yolov11/runs/detect/train/weights/best.pt')

# Video path and capture setup
video_path = "/home/nova/Videos/ty.mp4"
cap = cv2.VideoCapture(video_path)

# Video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_interval = fps  # Process one frame per second
g = 9.81  # Acceleration due to gravity (m/s^2)

# Calculate pixels-to-meter scaling factor
stadium_length_meters = 400  # Real-world stadium length in meters
stadium_pixel_length = 1920  # Example pixel length (update with actual value)
pixels_to_meter = stadium_length_meters / stadium_pixel_length
print(f"Pixels-to-Meter Scaling Factor: {pixels_to_meter:.4f} meters per pixel")

# Tracking variables
previous_positions = {}
previous_times = {}
results_list = []

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Get current frame ID
    frame_id = int(cap.get(cv2.CAP_PROP_POS_FRAMES))
    if frame_id % frame_interval != 0:
        continue

    # Predict with YOLO
    results = model.predict(frame)
    boxes = results[0].boxes.xyxy.tolist()
    clss = results[0].boxes.cls.tolist()
    current_time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000.0  # Time in seconds

    for box, cls in zip(boxes, clss):
        class_name = model.names[int(cls)]
        if class_name != "pitcher":  # Process only objects labeled as "pitcher"
            continue

        # Calculate current position (center of bounding box)
        x_center = (box[0] + box[2]) / 2
        y_center = (box[1] + box[3]) / 2
        current_position = (x_center, y_center)

        if class_name in previous_positions:
            prev_position = previous_positions[class_name]
            prev_time = previous_times[class_name]
            dt = current_time - prev_time

            if dt > 0:
                # Calculate velocity and derived parameters
                dx = (current_position[0] - prev_position[0]) * pixels_to_meter
                dy = (prev_position[1] - current_position[1]) * pixels_to_meter
                
                velocity_x = dx / dt
                velocity_y = dy / dt
                exit_velocity = np.sqrt(velocity_x**2 + velocity_y**2)
                launch_angle = np.degrees(np.arctan2(velocity_y, velocity_x))

                # Debugging output
                print(f"Frame {frame_id}:")
                print(f"  dx (m): {dx}, dy (m): {dy}, dt (s): {dt}")
                print(f"  Velocity X: {velocity_x:.2f} m/s, Velocity Y: {velocity_y:.2f} m/s")
                print(f"  ExitVelocity: {exit_velocity:.2f} m/s, LaunchAngle: {launch_angle:.1f}°")

                # Calculate hit distance
                hit_distance = (exit_velocity**2 * np.sin(2 * np.radians(launch_angle))) / g
                results_list.append({
                    "ExitVelocity": round(exit_velocity, 2),
                    "HitDistance": round(hit_distance, 2),
                    "LaunchAngle": round(launch_angle, 1),
                    "Timestamp": round(current_time, 2)
                })
        
        # Update previous positions and times
        previous_positions[class_name] = current_position
        previous_times[class_name] = current_time

cap.release()

# Print final results
print(f"\nFinal Results ({len(results_list)} frames):")
for result in results_list:
    print(f"ExitVelocity: {result['ExitVelocity']} m/s, "
          f"HitDistance: {result['HitDistance']} m, "
          f"LaunchAngle: {result['LaunchAngle']}°, "
          f"Timestamp: {result['Timestamp']} s")
# Out:
# Pixels-to-Meter Scaling Factor: 0.1042 meters per pixel
#
# 0: 384x640 (no detections), 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.3ms
# Speed: 3.3ms preprocess, 10.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 batters, 1 homeplate, 1 pitcher, 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 batters, 1 homeplate, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 homeplate, 1 pitcher, 6.7ms
# Speed: 2.2ms preprocess, 6.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 145:
#   dx (m): 5.210326512654623, dy (m): -3.722689946492513, dt (s): 1.9352666666666667
#   Velocity X: 2.69 m/s, Velocity Y: -1.92 m/s
#   ExitVelocity: 3.31 m/s, LaunchAngle: -35.5°
#
# ...

# %%
from ultralytics import YOLO
import cv2
from ultralytics.utils.plotting import Annotator, colors
import os
from datetime import datetime
import math
import numpy as np

# Load the YOLO model
detection_model = YOLO('/home/nova/Videos/Google-ai-hack/RoboUmp.v4i.yolov11/runs/detect/train/weights/best.pt')

# Class mapping
CLASS_MAP = {0: 'baseball', 1: 'batter', 2: 'homeplate', 3: 'pitcher'}

# Open the video file or camera feed
cap = cv2.VideoCapture("/home/nova/Videos/try.mp4")

# Get video properties
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Create output directories with timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
base_output_dir = f"baseball_analysis_{timestamp}"
folders = {
    'complete_detections': os.path.join(base_output_dir, "complete_detections"),
    'hit_analysis': os.path.join(base_output_dir, "hit_analysis")
}

for folder in folders.values():
    os.makedirs(folder, exist_ok=True)

class BallTracker:
    def __init__(self, fps, buffer_size=10):
        self.positions = []
        self.buffer_size = buffer_size
        self.hit_detected = False
        self.launch_angle = None
        self.exit_velocity = None
        self.hit_frame = None
        self.fps = fps
        # Approximate real-world scale (pixels to feet)
        self.scale_factor = 0.5  # This needs to be calibrated based on known distances in the video
        
    def add_position(self, x, y, frame):
        self.positions.append((x, y, frame))
        if len(self.positions) > self.buffer_size:
            self.positions.pop(0)
    
    def calculate_launch_angle(self):
        if len(self.positions) < 3:
            return None
        
        pos_1 = self.positions[-3]
        pos_2 = self.positions[-2]
        pos_3 = self.positions[-1]
        
        if pos_3[1] < pos_2[1] < pos_1[1]:  # Ball moving upward
            dx = pos_3[0] - pos_1[0]
            dy = pos_1[1] - pos_3[1]  # Invert y because image coordinates
            angle = math.degrees(math.atan2(dy, dx))
            return angle
        return None
    
    def calculate_exit_velocity(self):
        if len(self.positions) < 3:
            return None
        
        # Get the first three positions after hit
        pos_1 = self.positions[-3]
        pos_3 = self.positions[-1]
        
        # Calculate displacement in pixels
        dx = pos_3[0] - pos_1[0]
        dy = pos_3[1] - pos_1[1]
        displacement = math.sqrt(dx**2 + dy**2)
        
        # Convert to real-world distance (feet)
        distance_feet = displacement * self.scale_factor
        
        # Calculate time between positions
        time_between_frames = (pos_3[2] - pos_1[2]) / self.fps  # in seconds
        
        # Calculate velocity in feet per second
        velocity_fps = distance_feet / time_between_frames
        
        # Convert to miles per hour
        velocity_mph = velocity_fps * 0.681818  # Convert fps to mph
        
        return velocity_mph

def draw_bbox(img, box, label, color):
    """Draw bounding box with label"""
    x1, y1, x2, y2 = map(int, box)
    cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
    cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
    return (int((x1 + x2)/2), int((y1 + y2)/2))

def check_collision(box1, box2):
    """Check if two bounding boxes intersect"""
    x1, y1, x2, y2 = box1
    bx1, by1, bx2, by2 = box2
    return not (x2 < bx1 or x1 > bx2 or y2 < by1 or y1 > by2)

def draw_hit_analysis(frame, positions, launch_angle, exit_velocity):
    """Draw hit analysis visualization"""
    # Draw trajectory
    for i in range(len(positions)-1):
        cv2.line(frame, 
                (positions[i][0], positions[i][1]),
                (positions[i+1][0], positions[i+1][1]),
                (0, 255, 255), 2)
    
    # Create analysis text
    analysis_text = [
        f"Launch Angle: {launch_angle:.1f}°",
        f"Exit Velocity: {exit_velocity:.1f} MPH"
    ]
    
    # Draw analysis box
    y_offset = 30
    for text in analysis_text:
        cv2.putText(frame, text, (10, y_offset), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)
        y_offset += 40

# Initialize ball tracker with FPS
ball_tracker = BallTracker(fps)
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    frame_count += 1
    annotated_frame = frame.copy()
    
    # Detect objects
    detection_results = detection_model.predict(frame, conf=0.5)[0]
    
    # Track detected classes and objects
    detected_classes = set()
    baseball_bbox = None
    batter_bbox = None
    
    # Process and draw detections
    for box, cls_id in zip(detection_results.boxes.xyxy.tolist(), detection_results.boxes.cls.tolist()):
        class_name = CLASS_MAP[int(cls_id)]
        color = colors(int(cls_id))
        
        center = draw_bbox(annotated_frame, box, class_name, color)
        detected_classes.add(class_name)
        
        if class_name == 'baseball':
            baseball_bbox = box
            ball_tracker.add_position(center[0], center[1], frame_count)
        elif class_name == 'batter':
            batter_bbox = box
    
    # Check if all classes are detected
    all_classes_detected = all(class_name in detected_classes 
                             for class_name in CLASS_MAP.values())
    
    if all_classes_detected:
        # Check for ball-batter collision
        if baseball_bbox and batter_bbox and check_collision(baseball_bbox, batter_bbox):
            if not ball_tracker.hit_detected:
                ball_tracker.hit_detected = True
                ball_tracker.hit_frame = frame_count
                print(f"Hit detected in frame {frame_count}")
        
        # If hit was detected, calculate metrics
        if ball_tracker.hit_detected:
            # Calculate launch angle if not already calculated
            if not ball_tracker.launch_angle:
                angle = ball_tracker.calculate_launch_angle()
                if angle is not None:
                    ball_tracker.launch_angle = angle
                    print(f"Launch angle: {angle:.1f}°")
            
            # Calculate exit velocity if not already calculated
            if not ball_tracker.exit_velocity and ball_tracker.launch_angle:
                velocity = ball_tracker.calculate_exit_velocity()
                if velocity is not None:
                    ball_tracker.exit_velocity = velocity
                    print(f"Exit velocity: {velocity:.1f} MPH")
            
            # If we have both metrics, draw the analysis
            if ball_tracker.launch_angle and ball_tracker.exit_velocity:
                draw_hit_analysis(annotated_frame, 
                                ball_tracker.positions[-3:],
                                ball_tracker.launch_angle,
                                ball_tracker.exit_velocity)
                
                # Save frame with analysis
                analysis_path = os.path.join(folders['hit_analysis'], 
                                           f"hit_analysis_frame_{frame_count}.jpg")
                cv2.imwrite(analysis_path, annotated_frame)
        
        # Save frame with all detections
        detection_path = os.path.join(folders['complete_detections'], 
                                    f"complete_detection_frame_{frame_count}.jpg")
        cv2.imwrite(detection_path, annotated_frame)
        
        # Display frame
        cv2.imshow("Baseball Analysis", annotated_frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

print(f"\nAnalysis complete. Images saved in:\n"
      f"Complete Detections: {folders['complete_detections']}\n"
      f"Hit Analysis: {folders['hit_analysis']}")
# Out:
# 0: 384x640 1 batter, 1 pitcher, 3.8ms
# Speed: 1.0ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 4.5ms
# Speed: 1.0ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 3.8ms
# Speed: 1.2ms preprocess, 3.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 3.9ms
# Speed: 1.0ms preprocess, 3.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 4.2ms
# Speed: 0.9ms preprocess, 4.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 3.8ms
# Speed: 0.9ms preprocess, 3.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 4.2ms
# Speed: 1.1ms preprocess, 4.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
from ultralytics import YOLO
import cv2
from ultralytics.utils.plotting import Annotator, colors
import os
from datetime import datetime
import math
import numpy as np
import csv

# Load the YOLO model (assuming a custom trained model for detecting baseball, batter, etc.)
detection_model = YOLO('/home/nova/Videos/Google-ai-hack/RoboUmp.v4i.yolov11/runs/detect/train/weights/best.pt')

# Class mapping (you can expand this as needed based on your custom model's classes)
CLASS_MAP = {0: 'baseball', 1: 'batter', 2: 'homeplate', 3: 'pitcher'}

# Open the video file
cap = cv2.VideoCapture("/home/nova/Videos/try.mp4")

# Get video properties
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Create output directories with timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
base_output_dir = f"baseball_analysis_{timestamp}"
folders = {
    'complete_detections': os.path.join(base_output_dir, "complete_detections"),
    'hit_analysis': os.path.join(base_output_dir, "hit_analysis"),
    'statcast_data': os.path.join(base_output_dir, "statcast_data")
}

for folder in folders.values():
    os.makedirs(folder, exist_ok=True)

# Save the Statcast output to a CSV file
statcast_output_path = os.path.join(folders['statcast_data'], "statcast_output.csv")
with open(statcast_output_path, mode="w", newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Frame Number", "Pitch Speed (MPH)", "Exit Velocity (MPH)", "Launch Angle (Degrees)", "Distance Traveled (Feet)", "Hit Detected"])

# BallTracker class to calculate exit velocity, launch angle, etc.
class BallTracker:
    def __init__(self, fps, buffer_size=10):
        self.positions = []
        self.buffer_size = buffer_size
        self.hit_detected = False
        self.launch_angle = None
        self.exit_velocity = None
        self.hit_frame = None
        self.fps = fps
        self.scale_factor = 0.5  # Calibration factor (pixels to feet)

    def add_position(self, x, y, frame):
        self.positions.append((x, y, frame))
        if len(self.positions) > self.buffer_size:
            self.positions.pop(0)

    def calculate_launch_angle(self):
        if len(self.positions) < 3:
            return None

        pos_1 = self.positions[-3]
        pos_2 = self.positions[-2]
        pos_3 = self.positions[-1]

        if pos_3[1] < pos_2[1] < pos_1[1]:  # Ball moving upward
            dx = pos_3[0] - pos_1[0]
            dy = pos_1[1] - pos_3[1]  # Invert y-axis because image coordinates
            angle = math.degrees(math.atan2(dy, dx))
            return angle
        return None

    def calculate_exit_velocity(self):
        if len(self.positions) < 3:
            return None

        pos_1 = self.positions[-3]
        pos_3 = self.positions[-1]

        dx = pos_3[0] - pos_1[0]
        dy = pos_3[1] - pos_1[1]
        displacement = math.sqrt(dx**2 + dy**2)

        distance_feet = displacement * self.scale_factor
        time_between_frames = (pos_3[2] - pos_1[2]) / self.fps

        velocity_fps = distance_feet / time_between_frames
        velocity_mph = velocity_fps * 0.681818  # Convert fps to mph

        return velocity_mph

# Helper function to draw bounding boxes
def draw_bbox(img, box, label, color):
    x1, y1, x2, y2 = map(int, box)
    cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
    cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
    return (int((x1 + x2)/2), int((y1 + y2)/2))

# Helper function to check if two bounding boxes intersect
def check_collision(box1, box2):
    x1, y1, x2, y2 = box1
    bx1, by1, bx2, by2 = box2
    return not (x2 < bx1 or x1 > bx2 or y2 < by1 or y1 > by2)

# Helper function to draw the hit analysis
def draw_hit_analysis(frame, positions, launch_angle, exit_velocity):
    for i in range(len(positions) - 1):
        cv2.line(frame, (positions[i][0], positions[i][1]), (positions[i + 1][0], positions[i + 1][1]), (0, 255, 255), 2)

    analysis_text = [
        f"Launch Angle: {launch_angle:.1f}°",
        f"Exit Velocity: {exit_velocity:.1f} MPH"
    ]
    
    y_offset = 30
    for text in analysis_text:
        cv2.putText(frame, text, (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)
        y_offset += 40

# Initialize the ball tracker with the FPS of the video
ball_tracker = BallTracker(fps)
frame_count = 0
pitch_speed = 95  # Assume pitch speed is given (in MPH)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_count += 1
    annotated_frame = frame.copy()

    detection_results = detection_model.predict(frame, conf=0.5)[0]

    detected_classes = set()
    baseball_bbox = None
    batter_bbox = None

    for box, cls_id in zip(detection_results.boxes.xyxy.tolist(), detection_results.boxes.cls.tolist()):
        class_name = CLASS_MAP[int(cls_id)]
        color = colors(int(cls_id))

        center = draw_bbox(annotated_frame, box, class_name, color)
        detected_classes.add(class_name)

        if class_name == 'baseball':
            baseball_bbox = box
            ball_tracker.add_position(center[0], center[1], frame_count)
        elif class_name == 'batter':
            batter_bbox = box

    all_classes_detected = all(class_name in detected_classes for class_name in CLASS_MAP.values())

    if all_classes_detected:
        if baseball_bbox and batter_bbox and check_collision(baseball_bbox, batter_bbox):
            if not ball_tracker.hit_detected:
                ball_tracker.hit_detected = True
                ball_tracker.hit_frame = frame_count
                print(f"Hit detected in frame {frame_count}")

        if ball_tracker.hit_detected:
            if not ball_tracker.launch_angle:
                angle = ball_tracker.calculate_launch_angle()
                if angle is not None:
                    ball_tracker.launch_angle = angle
                    print(f"Launch angle: {angle:.1f}°")

            if not ball_tracker.exit_velocity and ball_tracker.launch_angle:
                velocity = ball_tracker.calculate_exit_velocity()
                if velocity is not None:
                    ball_tracker.exit_velocity = velocity
                    print(f"Exit velocity: {velocity:.1f} MPH")

            if ball_tracker.launch_angle and ball_tracker.exit_velocity:
                draw_hit_analysis(annotated_frame, ball_tracker.positions[-3:], ball_tracker.launch_angle, ball_tracker.exit_velocity)
                analysis_path = os.path.join(folders['hit_analysis'], f"hit_analysis_frame_{frame_count}.jpg")
                cv2.imwrite(analysis_path, annotated_frame)

            with open(statcast_output_path, mode="a", newline='') as file:
                writer = csv.writer(file)
                writer.writerow([frame_count, pitch_speed, ball_tracker.exit_velocity, ball_tracker.launch_angle, ball_tracker.exit_velocity * 10, "Yes"])

        detection_path = os.path.join(folders['complete_detections'], f"complete_detection_frame_{frame_count}.jpg")
        cv2.imwrite(detection_path, annotated_frame)

        cv2.imshow("Baseball Analysis", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

print(f"\nAnalysis complete. Images saved in:\n"
      f"Complete Detections: {folders['complete_detections']}\n"
      f"Hit Analysis: {folders['hit_analysis']}\n"
      f"Statcast Data saved in: {statcast_output_path}")
# Out:
# 0: 384x640 1 batter, 1 pitcher, 4.1ms
# Speed: 1.7ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 4.3ms
# Speed: 1.1ms preprocess, 4.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 4.7ms
# Speed: 1.2ms preprocess, 4.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 5.0ms
# Speed: 1.4ms preprocess, 5.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 4.8ms
# Speed: 1.4ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
from ultralytics import YOLO
import cv2
from ultralytics.utils.plotting import Annotator, colors
import os
from datetime import datetime
import math
import numpy as np
import csv

# Load the YOLO model (assuming a custom trained model for detecting baseball, batter, etc.)
detection_model = YOLO('/home/nova/Videos/Google-ai-hack/RoboUmp.v4i.yolov11/runs/detect/train/weights/best.pt')

# Class mapping (you can expand this as needed based on your custom model's classes)
CLASS_MAP = {0: 'baseball', 1: 'batter', 2: 'homeplate', 3: 'pitcher'}

# Open the video file
cap = cv2.VideoCapture("/home/nova/Videos/try.mp4")
# Get video properties
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Create output directories with timestamp
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
base_output_dir = f"baseball_analysis_{timestamp}"
folders = {
    'complete_detections': os.path.join(base_output_dir, "complete_detections"),
    'hit_analysis': os.path.join(base_output_dir, "hit_analysis"),
    'statcast_data': os.path.join(base_output_dir, "statcast_data")
}

for folder in folders.values():
    os.makedirs(folder, exist_ok=True)

# Save the Statcast output to a CSV file
statcast_output_path = os.path.join(folders['statcast_data'], "statcast_output.csv")
with open(statcast_output_path, mode="w", newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Frame Number", "Pitch Speed (MPH)", "Exit Velocity (MPH)", "Launch Angle (Degrees)", "Distance Traveled (Feet)", "Hit Detected"])

# BallTracker class to calculate exit velocity, launch angle, etc.
class BallTracker:
    def __init__(self, fps, buffer_size=10):
        self.positions = []
        self.buffer_size = buffer_size
        self.hit_detected = False
        self.launch_angle = None
        self.exit_velocity = None
        self.hit_frame = None
        self.fps = fps
        self.scale_factor = 0.5  # Calibration factor (pixels to feet)

    def add_position(self, x, y, frame):
        self.positions.append((x, y, frame))
        if len(self.positions) > self.buffer_size:
            self.positions.pop(0)

    def calculate_launch_angle(self):
        if len(self.positions) < 3:
            return None

        pos_1 = self.positions[-3]
        pos_2 = self.positions[-2]
        pos_3 = self.positions[-1]

        if pos_3[1] < pos_2[1] < pos_1[1]:  # Ball moving upward
            dx = pos_3[0] - pos_1[0]
            dy = pos_1[1] - pos_3[1]  # Invert y-axis because image coordinates
            angle = math.degrees(math.atan2(dy, dx))
            return angle
        return None

    def calculate_exit_velocity(self):
        if len(self.positions) < 3:
            return None

        pos_1 = self.positions[-3]
        pos_3 = self.positions[-1]

        dx = pos_3[0] - pos_1[0]
        dy = pos_3[1] - pos_1[1]
        displacement = math.sqrt(dx**2 + dy**2)

        distance_feet = displacement * self.scale_factor
        time_between_frames = (pos_3[2] - pos_1[2]) / self.fps

        velocity_fps = distance_feet / time_between_frames
        velocity_mph = velocity_fps * 0.681818  # Convert fps to mph

        return velocity_mph

# Helper function to draw bounding boxes
def draw_bbox(img, box, label, color):
    x1, y1, x2, y2 = map(int, box)
    cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)
    cv2.putText(img, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
    return (int((x1 + x2)/2), int((y1 + y2)/2))

# Helper function to check if two bounding boxes intersect
def check_collision(box1, box2):
    x1, y1, x2, y2 = box1
    bx1, by1, bx2, by2 = box2
    return not (x2 < bx1 or x1 > bx2 or y2 < by1 or y1 > by2)

# Helper function to draw the hit analysis
def draw_hit_analysis(frame, positions, launch_angle, exit_velocity):
    for i in range(len(positions) - 1):
        cv2.line(frame, (positions[i][0], positions[i][1]), (positions[i + 1][0], positions[i + 1][1]), (0, 255, 255), 2)

    analysis_text = [
        f"Launch Angle: {launch_angle:.1f}°",
        f"Exit Velocity: {exit_velocity:.1f} MPH"
    ]
    
    y_offset = 30
    for text in analysis_text:
        cv2.putText(frame, text, (10, y_offset), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)
        y_offset += 40

# Initialize the ball tracker with the FPS of the video
ball_tracker = BallTracker(fps)
frame_count = 0
pitch_speed = 95  # Assume pitch speed is given (in MPH)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_count += 1
    annotated_frame = frame.copy()

    detection_results = detection_model.predict(frame, conf=0.5)[0]

    detected_classes = set()
    baseball_bbox = None
    batter_bbox = None

    for box, cls_id in zip(detection_results.boxes.xyxy.tolist(), detection_results.boxes.cls.tolist()):
        class_name = CLASS_MAP[int(cls_id)]
        color = colors(int(cls_id))

        center = draw_bbox(annotated_frame, box, class_name, color)
        detected_classes.add(class_name)

        if class_name == 'baseball':
            baseball_bbox = box
            ball_tracker.add_position(center[0], center[1], frame_count)
        elif class_name == 'batter':
            batter_bbox = box

    all_classes_detected = all(class_name in detected_classes for class_name in CLASS_MAP.values())

    if all_classes_detected:
        # Check for collision (hit detection)
        if baseball_bbox and batter_bbox and check_collision(baseball_bbox, batter_bbox):
            if not ball_tracker.hit_detected:
                ball_tracker.hit_detected = True
                ball_tracker.hit_frame = frame_count
                print(f"Hit detected in frame {frame_count}")

        if ball_tracker.hit_detected:
            # Calculate launch angle
            if not ball_tracker.launch_angle:
                angle = ball_tracker.calculate_launch_angle()
                if angle is not None:
                    ball_tracker.launch_angle = angle
                    print(f"Launch angle: {angle:.1f}°")

            # Calculate exit velocity
            if not ball_tracker.exit_velocity and ball_tracker.launch_angle:
                velocity = ball_tracker.calculate_exit_velocity()
                if velocity is not None:
                    ball_tracker.exit_velocity = velocity
                    print(f"Exit velocity: {velocity:.1f} MPH")

            # Save analysis if both metrics are calculated
            if ball_tracker.launch_angle and ball_tracker.exit_velocity:
                draw_hit_analysis(annotated_frame, ball_tracker.positions[-3:], ball_tracker.launch_angle, ball_tracker.exit_velocity)
                analysis_path = os.path.join(folders['hit_analysis'], f"hit_analysis_frame_{frame_count}.jpg")
                cv2.imwrite(analysis_path, annotated_frame)

            # Write to CSV file
            with open(statcast_output_path, mode="a", newline='') as file:
                writer = csv.writer(file)
                distance_travelled = ball_tracker.exit_velocity * 10  # Placeholder for distance calculation
                writer.writerow([frame_count, pitch_speed, ball_tracker.exit_velocity, ball_tracker.launch_angle, distance_travelled, "Yes"])

        # Save the complete detection frame
        detection_path = os.path.join(folders['complete_detections'], f"complete_detection_frame_{frame_count}.jpg")
        cv2.imwrite(detection_path, annotated_frame)

        # Display the annotated frame
        cv2.imshow("Baseball Analysis", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

print(f"\nAnalysis complete. Images saved in:\n"
      f"Complete Detections: {folders['complete_detections']}\n"
      f"Hit Analysis: {folders['hit_analysis']}\n"
      f"Statcast Data saved in: {statcast_output_path}")
# Out:
# 0: 384x640 1 batter, 1 pitcher, 4.1ms
# Speed: 1.1ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 4.1ms
# Speed: 1.4ms preprocess, 4.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 4.1ms
# Speed: 1.2ms preprocess, 4.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 4.0ms
# Speed: 1.1ms preprocess, 4.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 3.9ms
# Speed: 1.0ms preprocess, 3.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 3.9ms
# Speed: 1.1ms preprocess, 3.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 batter, 1 pitcher, 3.8ms
# Speed: 1.0ms preprocess, 3.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
